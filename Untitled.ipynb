# %%
# %load_ext autoreload

# %autoreload 2
import tnetwork as tn

# %%
my_scenario = tn.ComScenario()
[com1,com2] = my_scenario.INITIALIZE([6,6],["c1","c2"])
(com2,com3)=my_scenario.THESEUS(com2,delay=20)
my_scenario.DEATH(com2,delay=10)

#visualization
(generated_network_IG,generated_comunities_IG) = my_scenario.run()

tn.plot_longitudinal(generated_network_IG,generated_comunities_IG,height=300)
generated_network_SN = generated_network_IG.to_DynGraphSN(slices=1)
generated_communities_SN = generated_comunities_IG.to_DynCommunitiesSN(slices=1)
# Out:
# 100% (8 of 8) |##########################| Elapsed Time: 0:00:00 ETA:  00:00:00/usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2327: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())

# %%
from tnetwork.DCD.externals.MuchaLeiden import transversal_network_leidenalg

# %%
# %load_ext autoreload

# %autoreload 2
import tnetwork as tn
comfounds = transversal_network_leidenalg(generated_network_SN)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INITIALISING MUCHA leidenalg
# sucessfully finished MUCHA

# %%
tn.plot_longitudinal(generated_network_SN,comfounds,height=300)

# %%
# %load_ext autoreload

# %autoreload 2
from tnetwork.DCD.externals.estrangement_confinement import estrangement_confinement
import tnetwork as tn

comfounds = estrangement_confinement(generated_network_SN,minrepeats=5,increpeats=5,maxfun=100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INITIALISING estrangement confinement
# 100% (101 of 101) |######################| Elapsed Time: 0:03:41 ETA:  00:00:00
# Done computing temporal communities for delta=0.050000
# sucessfully estrangement confinement

# %%
tn.plot_longitudinal(generated_network_SN,comfounds,height=300)
